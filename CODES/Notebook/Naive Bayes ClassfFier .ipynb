# %% [markdown]
# ## Naive Bayes Algorithm

# %%
# importing the libraries
import pandas as pd
hearth_ds = pd.read_csv(r"E:\Sankhyana Training\Datasets\Naive_Bayes_Heart_Disease.csv")    
hearth_ds.head()
# Out:
#    age  sex  Chest_Pain  Blood_Pressure(mm Hg)  cholestoral (mg/dl)  \
# 0   63    1           3                    145                  233
# 1   37    1           2                    130                  250
# 2   41    0           1                    130                  204
# 3   56    1           1                    120                  236
# 4   57    0           0                    120                  354
#
#    Fasting_Blood_Sugar  resting electrocardiographic  Maximum_Heart_Rate  \
# 0                    1                             0                 150
# 1                    0                             1                 187
# 2                    0                             0                 172
# 3                    0                             1                 178
# 4                    0                             1                 163
#
#    Excersize_Includes  ST Depression  Slope_of_Excersize  Number_of_vessels  \
# ...

# %%
# shape 
hearth_ds.shape
# Out:
# (303, 14)

# %%
hearth_ds.describe()
# Out:
#               age         sex  Chest_Pain  Blood_Pressure(mm Hg)  \
# count  303.000000  303.000000  303.000000             303.000000
# mean    54.366337    0.683168    0.966997             131.623762
# std      9.082101    0.466011    1.032052              17.538143
# min     29.000000    0.000000    0.000000              94.000000
# 25%     47.500000    0.000000    0.000000             120.000000
# 50%     55.000000    1.000000    1.000000             130.000000
# 75%     61.000000    1.000000    2.000000             140.000000
# max     77.000000    1.000000    3.000000             200.000000
#
#        cholestoral (mg/dl)  Fasting_Blood_Sugar  resting electrocardiographic  \
# count           303.000000           303.000000                    303.000000
# mean            246.264026             0.148515                      0.528053
# std              51.830751             0.356198                      0.525860
# ...

# %%
hearth_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   age                           303 non-null    int64
#  1   sex                           303 non-null    int64
#  2   Chest_Pain                    303 non-null    int64
#  3   Blood_Pressure(mm Hg)         303 non-null    int64
#  4   cholestoral (mg/dl)           303 non-null    int64
#  5   Fasting_Blood_Sugar           303 non-null    int64
#  6   resting electrocardiographic  303 non-null    int64
#  7   Maximum_Heart_Rate            303 non-null    int64
#  8   Excersize_Includes            303 non-null    int64
#  9   ST Depression                 303 non-null    float64
#  10  Slope_of_Excersize            303 non-null    int64
#  11  Number_of_vessels             303 non-null    int64
#  12  Thalassemia                   303 non-null    int64
# ...

# %%
hearth_ds.isnull().sum()
# Out:
# age                             0
# sex                             0
# Chest_Pain                      0
# Blood_Pressure(mm Hg)           0
# cholestoral (mg/dl)             0
# Fasting_Blood_Sugar             0
# resting electrocardiographic    0
# Maximum_Heart_Rate              0
# Excersize_Includes              0
# ST Depression                   0
# Slope_of_Excersize              0
# Number_of_vessels               0
# Thalassemia                     0
# Diagnosis_of_Heart_Disease      0
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
hearth_ds.head()
# Out:
#    age  sex  Chest_Pain  Blood_Pressure(mm Hg)  cholestoral (mg/dl)  \
# 0   63    1           3                    145                  233
# 1   37    1           2                    130                  250
# 2   41    0           1                    130                  204
# 3   56    1           1                    120                  236
# 4   57    0           0                    120                  354
#
#    Fasting_Blood_Sugar  resting electrocardiographic  Maximum_Heart_Rate  \
# 0                    1                             0                 150
# 1                    0                             1                 187
# 2                    0                             0                 172
# 3                    0                             1                 178
# 4                    0                             1                 163
#
#    Excersize_Includes  ST Depression  Slope_of_Excersize  Number_of_vessels  \
# ...

# %%
import matplotlib.pyplot as plt

# ploting the cross tapulation data for the bar chart
pd.crosstab(hearth_ds['sex'], hearth_ds['Diagnosis_of_Heart_Disease']).plot(kind='bar')

plt.show()

# %%
import seaborn as sns

sns.scatterplot(x= 'age', y= "Blood_Pressure(mm Hg)", hue= "Diagnosis_of_Heart_Disease", data = hearth_ds )
# Out:
# <AxesSubplot:xlabel='age', ylabel='Blood_Pressure(mm Hg)'>

# %%
sns.scatterplot(x= 'age', y= "Blood_Pressure(mm Hg)", hue= "Diagnosis_of_Heart_Disease", data = hearth_ds )
# Out:
# <AxesSubplot:xlabel='age', ylabel='Blood_Pressure(mm Hg)'>

# %%
sns.scatterplot(x= 'age', y= "cholestoral (mg/dl)", hue= "Diagnosis_of_Heart_Disease", data = hearth_ds )
# Out:
# <AxesSubplot:xlabel='age', ylabel='cholestoral (mg/dl)'>

# %%
pd.crosstab(hearth_ds ['Excersize_Includes'], hearth_ds ['Diagnosis_of_Heart_Disease'] )
# Out:
# Diagnosis_of_Heart_Disease   0    1
# Excersize_Includes
# 0                           62  142
# 1                           76   23

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
data = hearth_ds.iloc[:, :13] #input features

target= hearth_ds.iloc[:, 13] # target feature

# %%
data.head()
# Out:
#    age  sex  Chest_Pain  Blood_Pressure(mm Hg)  cholestoral (mg/dl)  \
# 0   63    1           3                    145                  233
# 1   37    1           2                    130                  250
# 2   41    0           1                    130                  204
# 3   56    1           1                    120                  236
# 4   57    0           0                    120                  354
#
#    Fasting_Blood_Sugar  resting electrocardiographic  Maximum_Heart_Rate  \
# 0                    1                             0                 150
# 1                    0                             1                 187
# 2                    0                             0                 172
# 3                    0                             1                 178
# 4                    0                             1                 163
#
#    Excersize_Includes  ST Depression  Slope_of_Excersize  Number_of_vessels  \
# ...

# %%
target
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: Diagnosis_of_Heart_Disease, Length: 303, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler= StandardScaler()

data= scaler.fit_transform(data)

# %%
# splitting the data

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split (data, target, train_size = 0.7)

# %%
# model training
model= BernoulliNB()
model.fit(X_train, Y_train)
# Out:
# BernoulliNB()

# %%
# model prediction
pred = model.predict(X_test)

# %%
#checking the model accuracy

from sklearn.metrics import *
accuracy_score (Y_test, pred)
# Out:
# 0.8241758241758241
