# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_cars = pd.read_csv("E:\Sankhyana Training\Datasets\car data.csv")
df_cars.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59     27000.0    Petrol
# 1      sx4  2013           4.75           9.54     43000.0    Diesel
# 2     ciaz  2017           7.25           9.85      6900.0    Petrol
# 3  wagon r  2011           2.85           4.15      5200.0    Petrol
# 4    swift  2014           4.60           6.87     42450.0    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df_cars.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6     33988.0    Diesel
# 297     brio  2015           4.00            5.9     60000.0    Petrol
# 298     city  2009           3.35           11.0     87934.0    Petrol
# 299     city  2017          11.50           12.5      9000.0    Diesel
# 300     brio  2016           5.30            5.9      5464.0    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
df_cars.head(20)
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0            ritz  2014           3.35           5.59     27000.0    Petrol
# 1             sx4  2013           4.75           9.54     43000.0    Diesel
# 2            ciaz  2017           7.25           9.85      6900.0    Petrol
# 3         wagon r  2011           2.85           4.15      5200.0    Petrol
# 4           swift  2014           4.60           6.87     42450.0    Diesel
# 5   vitara brezza  2018           9.25           9.83      2071.0    Diesel
# 6            ciaz  2015           6.75           8.12     18796.0    Petrol
# 7         s cross  2015           6.50           8.61     33429.0    Diesel
# 8            ciaz  2016           8.75           8.89     20273.0    Diesel
# 9            ciaz  2015           7.45           8.92     42367.0    Diesel
# 10       alto 800  2017           2.85           3.60      2135.0    Petrol
# ...

# %%
df_cars.shape
# Out:
# (301, 9)

# %%
df_cars.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     299.000000  301.000000
# mean   2013.624585       4.711960       7.694319   36943.598662    0.043189
# std       2.889393       5.188605       8.743201   39015.900449    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48883.500000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
# checking for datatypes in each column

df_cars.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven       float64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# dtype: object

# %%
# checking for null values
df_cars.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       2
# Fuel_Type        0
# Seller_Type      1
# Transmission     0
# Owner            0
# dtype: int64

# %%
# droping a row from a dataset

df_cars1= df_cars.drop([299], axis=0)
df_cars1.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 295     city  2015           8.55          13.09     60076.0    Diesel
# 296     city  2016           9.50          11.60     33988.0    Diesel
# 297     brio  2015           4.00           5.90     60000.0    Petrol
# 298     city  2009           3.35          11.00     87934.0    Petrol
# 300     brio  2016           5.30           5.90      5464.0    Petrol
#
#     Seller_Type Transmission  Owner
# 295      Dealer       Manual      0
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
df_cars2.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven
# 0     ritz  2014           3.35           5.59     27000.0
# 1      sx4  2013           4.75           9.54     43000.0
# 2     ciaz  2017           7.25           9.85      6900.0
# 3  wagon r  2011           2.85           4.15      5200.0
# 4    swift  2014           4.60           6.87     42450.0

# %%
df_cars5= df_cars2.drop(['Car_Name'], axis=1)

# %%
df_cars5.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven
# 0  2014           3.35           5.59     27000.0
# 1  2013           4.75           9.54     43000.0
# 2  2017           7.25           9.85      6900.0
# 3  2011           2.85           4.15      5200.0
# 4  2014           4.60           6.87     42450.0

# %%
# Renaming a column
df_cars3 = df_cars.rename(columns={'Year':"Manufacture_Year"})
df_cars3.head()
# Out:
#   Car_Name  Manufacture_Year  Selling_Price  Present_Price  Kms_Driven  \
# 0     ritz              2014           3.35           5.59     27000.0
# 1      sx4              2013           4.75           9.54     43000.0
# 2     ciaz              2017           7.25           9.85      6900.0
# 3  wagon r              2011           2.85           4.15      5200.0
# 4    swift              2014           4.60           6.87     42450.0
#
#   Fuel_Type Seller_Type Transmission  Owner
# 0    Petrol      Dealer       Manual      0
# 1    Diesel      Dealer       Manual      0
# 2    Petrol      Dealer       Manual      0
# 3    Petrol      Dealer       Manual      0
# 4    Diesel      Dealer       Manual      0

# %%
# Checking for duplicate rows

duplicate_car= df_cars[df_cars.duplicated()]
duplicate_car.shape
# Out:
# (2, 9)

# %%
duplicate_car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 51  fortuner  2015           23.0          30.61     40000.0    Diesel
# 93  fortuner  2015           23.0          30.61     40000.0    Diesel
#
#    Seller_Type Transmission  Owner
# 51      Dealer    Automatic      0
# 93      Dealer    Automatic      0

# %%
df_cars4=df_cars.drop_duplicates()
df_cars4.shape
# Out:
# (299, 9)

# %%
df_cars4
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59     27000.0    Petrol
# 1        sx4  2013           4.75           9.54     43000.0    Diesel
# 2       ciaz  2017           7.25           9.85      6900.0    Petrol
# 3    wagon r  2011           2.85           4.15      5200.0    Petrol
# 4      swift  2014           4.60           6.87     42450.0    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60     33988.0    Diesel
# 297     brio  2015           4.00           5.90     60000.0    Petrol
# 298     city  2009           3.35          11.00     87934.0    Petrol
# 299     city  2017          11.50          12.50      9000.0    Diesel
# 300     brio  2016           5.30           5.90      5464.0    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
duplicate_car= df_cars4[df_cars4.duplicated()]
duplicate_car.shape
# Out:
# (0, 9)

# %%
duplicate_car
# Out:
# Empty DataFrame
# Columns: [Car_Name, Year, Selling_Price, Present_Price, Kms_Driven, Fuel_Type, Seller_Type, Transmission, Owner]
# Index: []

# %%
df_cars4.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       2
# Fuel_Type        0
# Seller_Type      1
# Transmission     0
# Owner            0
# dtype: int64

# %%
#Dropping the null values
df_cars5=df_cars4.dropna()
df_cars5.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
# checking for outliers

# %%
sns.boxplot(x=df_cars5['Kms_Driven'], orient='h')
# Out:
# <AxesSubplot:xlabel='Kms_Driven'>

# %%
sns.boxplot(x=df_cars5['Selling_Price'], orient='h')
# Out:
# <AxesSubplot:xlabel='Selling_Price'>

# %%
sns.boxplot(x=df_cars5['Present_Price'], orient='h')
# Out:
# <AxesSubplot:xlabel='Present_Price'>

# %%
df_cars5.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59     27000.0    Petrol
# 1      sx4  2013           4.75           9.54     43000.0    Diesel
# 2     ciaz  2017           7.25           9.85      6900.0    Petrol
# 3  wagon r  2011           2.85           4.15      5200.0    Petrol
# 4    swift  2014           4.60           6.87     42450.0    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df_cars5.Year.value_counts().nlargest(20).plot(kind='bar', figsize=(12, 6))
plt.title("Cars manufactured per year")
plt.xlabel('Year')
plt.ylabel('Number of cars Manufactured')
# Out:
# Text(0, 0.5, 'Number of cars Manufactured')

# %%
sns.scatterplot(x=df_cars5['Kms_Driven'], y=df_cars5['Present_Price'])
plt.title("Scatter plot for Kms_Drivenr against 'Present_Price'")
plt.xlabel('Kms_Driven')
plt.ylabel('Present_Price')
# Out:
# Text(0, 0.5, 'Present_Price')

# %%
sns.scatterplot(x=df_cars5['Selling_Price'], y=df_cars5['Present_Price'])
plt.title("Scatter plot for Selling_Price against 'Present_Price'")
plt.xlabel('Selling_Price')
plt.ylabel('Present_Price')
# Out:
# Text(0, 0.5, 'Present_Price')

# %%
# Scatter plot with line of best fit
sns.scatterplot(x=df_cars5['Selling_Price'], y=df_cars5['Present_Price'])
sns.regplot(x=df_cars5['Selling_Price'], y=df_cars5['Present_Price'], scatter=False, color='red')
#use regplot function to plot a line of best fit
plt.title("Scatter plot for Selling_Price against 'Present_Price'")
plt.xlabel('Selling_Price')
plt.ylabel('Present_Price')
plt.show()
