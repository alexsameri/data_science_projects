# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ames_df = pd.read_csv(r"C:\Users\Alex Sameri\Desktop\data_science_projects\CODES\ML Algorithms Project 1\AmesHousing.csv")
ames_df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %%
ames_df.isnull().sum()
# Out:
# Order               0
# PID                 0
# MS SubClass         0
# MS Zoning           0
# Lot Frontage      490
#                  ...
# Mo Sold             0
# Yr Sold             0
# Sale Type           0
# Sale Condition      0
# SalePrice           0
# Length: 82, dtype: int64

# %%
ames_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
ames_df.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
ames_df1 = ames_df.fillna(method="bfill")
# Out:
# C:\Users\Alex Sameri\AppData\Local\Temp\ipykernel_16132\2918651206.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ames_df1 = ames_df.fillna(method="bfill")

# %%
ames_df1.columns
# Out:
# Index(['Order', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
# ...

# %%
ames_df1.describe()
# Out:
#             Order           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2930.00000  2.930000e+03  2930.000000   2930.000000    2930.000000
# mean   1465.50000  7.144645e+08    57.387372     69.679181   10147.921843
# std     845.96247  1.887308e+08    42.638025     24.240378    7880.017759
# min       1.00000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     733.25000  5.284770e+08    20.000000     59.000000    7440.250000
# 50%    1465.50000  5.354536e+08    50.000000     69.000000    9436.500000
# 75%    2197.75000  9.071811e+08    70.000000     80.000000   11555.250000
# max    2930.00000  1.007100e+09   190.000000    313.000000  215245.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2930.000000   2930.000000  2930.000000     2930.000000   2930.000000
# mean       6.094881      5.563140  1971.356314     1984.266553    101.489761
# ...

# %%
from sklearn.preprocessing import StandardScaler

le = StandardScaler()

# %%
ames_df1['Age'] = ames_df1['Yr Sold'] - ames_df1['Year Built']
ames_df1['TotalSF'] = ames_df1['Total Bsmt SF'] + ames_df1['1st Flr SF'] + ames_df1['2nd Flr SF']
ames_df1['TotalBathrooms'] = ames_df1['Full Bath'] + 0.5 * ames_df1['Half Bath'] + ames_df1['Bsmt Full Bath'] + 0.5 * ames_df1['Bsmt Half Bath']

# %%
ames_df2 = ames_df1[['Age', 'TotalSF', 'TotalBathrooms', 'SalePrice', 'Overall Cond']]
ames_df2.head()
# Out:
#    Age  TotalSF  TotalBathrooms  SalePrice  Overall Cond
# 0   50   2736.0             2.0     215000             5
# 1   49   1778.0             1.0     105000             6
# 2   52   2658.0             1.5     172000             6
# 3   42   4220.0             3.5     244000             5
# 4   13   2557.0             2.5     189900             5

# %%
plt.figure(figsize=(10, 10))
plt.scatter(ames_df2.Age, ames_df2.SalePrice)
plt.xlabel('Age')
plt.ylabel('SalePrice')
plt.title('Building age vs Salprice')
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.scatter(ames_df2.TotalSF, ames_df2.SalePrice)
plt.xlabel('TotalSF')
plt.ylabel('SalePrice')
plt.title('Building TotalSF vs Salprice')
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.scatter(ames_df2.TotalBathrooms, ames_df2.SalePrice)
plt.xlabel('TotalBathrooms')
plt.ylabel('SalePrice')
plt.title('Building TotalBathrooms vs Salprice')
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.scatter(ames_df2['Overall Cond'], ames_df2.SalePrice)
plt.xlabel('Overall Cond')
plt.ylabel('SalePrice')
plt.title('Building Overall condition vs Salprice')
plt.show()

# %%
train= ames_df2[: (int((len(ames_df2)*0.8)))]
test= ames_df2[(int((len(ames_df2)*0.8))):]

# %%
train.shape
# Out:
# (2344, 5)

# %%
test.shape
# Out:
# (586, 5)

# %%
from sklearn import linear_model
regr =  linear_model.LinearRegression()
train_y = np.array(train[['SalePrice']])
train_x = np.array(train[['TotalBathrooms', 'Overall Cond', 'TotalSF', 'Age']])
regr.fit(train_x, train_y)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
test_x = np.array(test[['TotalBathrooms', 'Overall Cond', 'TotalSF', 'Age']])
test_y = np.array(test[['SalePrice']])
test_y_ = regr.predict(test_x)
print("Accuracy: %.2f" % r2_score(test_y_, test_y))
# Out:
# Accuracy: 0.66
